# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
stocks =["INFY", "AAPL", "GOOGL", "TSLA", "BTC-USD", "005930.KS", "DOGE-USD", "RELIANCE.NS", "META", "IBM", "ORCL", "ERF.PA", "NVDA", "SOL-USD"]

# %%
import datetime
dict={}
for s in stocks:
   da=yf.Ticker(s)
   da=da.history(period="1y")
   da=da.reset_index()
   dict[s]=da
# yesterday = datetime.datetime.today() - datetime.timedelta(days=2)
# yesterday_str = yesterday.strftime("%Y-%m-%d")

# # Get data from 1 year ago to yesterday
# one_year_ago = (datetime.datetime.today() - datetime.timedelta(days=365)).strftime("%Y-%m-%d")
# for s in stocks:
#     da = yf.Ticker(s)
#     da = da.history(start=one_year_ago, end=yesterday_str)  # Corrected: Use start & end instead of period
#     da = da.reset_index()
#     dict[s] = da

# %%
print(yf.Ticker(s))
# Out:
# yfinance.Ticker object <SOL-USD>

# %%
dict["INFY"]
# Out:
#                          Date       Open       High        Low      Close  \
# 0   2024-02-15 00:00:00-05:00  19.642432  19.700574  19.564909  19.681192
# 1   2024-02-16 00:00:00-05:00  19.719955  19.942834  19.632741  19.836239
# 2   2024-02-20 00:00:00-05:00  19.652122  19.768405  19.371099  19.400171
# 3   2024-02-21 00:00:00-05:00  19.177293  19.322649  19.070698  19.167603
# 4   2024-02-22 00:00:00-05:00  19.574599  19.729645  19.516456  19.681192
# ..                        ...        ...        ...        ...        ...
# 246 2025-02-10 00:00:00-05:00  21.799999  21.879999  21.709999  21.870001
# 247 2025-02-11 00:00:00-05:00  21.750000  21.990000  21.639999  21.969999
# 248 2025-02-12 00:00:00-05:00  21.590000  21.750000  21.510000  21.750000
# 249 2025-02-13 00:00:00-05:00  21.580000  21.760000  21.500000  21.740000
# 250 2025-02-14 00:00:00-05:00  21.730000  21.750000  21.540001  21.570000
#
#       Volume  Dividends  Stock Splits
# 0    5247500        0.0           0.0
# ...

# %%
df=[]
for stock,data in dict.items():
    data["Stock"]=stock
    df.append(data)
    comb_df=pd.concat(df,ignore_index=True)

# %%
comb_df
# Out:
#                            Date        Open        High         Low  \
# 0     2024-02-15 00:00:00-05:00   19.642432   19.700574   19.564909
# 1     2024-02-16 00:00:00-05:00   19.719955   19.942834   19.632741
# 2     2024-02-20 00:00:00-05:00   19.652122   19.768405   19.371099
# 3     2024-02-21 00:00:00-05:00   19.177293   19.322649   19.070698
# 4     2024-02-22 00:00:00-05:00   19.574599   19.729645   19.516456
# ...                         ...         ...         ...         ...
# 3851  2025-02-11 00:00:00+00:00  200.358917  205.924194  195.321503
# 3852  2025-02-12 00:00:00+00:00  197.983856  198.449814  189.608429
# 3853  2025-02-13 00:00:00+00:00  196.773804  198.260757  189.427719
# 3854  2025-02-14 00:00:00+00:00  194.454559  205.125015  194.354050
# 3855  2025-02-16 00:00:00+00:00  194.474197  195.247986  193.230530
#
#            Close      Volume  Dividends  Stock Splits    Stock
# 0      19.681192     5247500        0.0           0.0     INFY
# ...

# %%
df=comb_df

# %%
df.info
# Out:
# <bound method DataFrame.info of                            Date        Open        High         Low  \
# 0     2024-02-15 00:00:00-05:00   19.642432   19.700574   19.564909
# 1     2024-02-16 00:00:00-05:00   19.719955   19.942834   19.632741
# 2     2024-02-20 00:00:00-05:00   19.652122   19.768405   19.371099
# 3     2024-02-21 00:00:00-05:00   19.177293   19.322649   19.070698
# 4     2024-02-22 00:00:00-05:00   19.574599   19.729645   19.516456
# ...                         ...         ...         ...         ...
# 3851  2025-02-11 00:00:00+00:00  200.358917  205.924194  195.321503
# 3852  2025-02-12 00:00:00+00:00  197.983856  198.449814  189.608429
# 3853  2025-02-13 00:00:00+00:00  196.773804  198.260757  189.427719
# 3854  2025-02-14 00:00:00+00:00  194.454559  205.125015  194.354050
# 3855  2025-02-16 00:00:00+00:00  194.474197  195.247986  193.230530
#
#            Close      Volume  Dividends  Stock Splits    Stock
# ...

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count    3856.000000    3856.000000    3856.000000    3856.000000
# mean    11443.061556   11634.448396   11253.825232   11449.193083
# std     26434.644032   26879.390305   25990.552307   26448.482773
# min         0.083592       0.085407       0.080831       0.083593
# 25%       108.853868     110.790934     105.765693     108.311890
# 50%       178.271940     180.825882     175.340004     178.127716
# 75%       536.201164     541.711203     527.488407     536.012115
# max    106147.296875  109114.882812  105291.734375  106146.265625
#
#              Volume    Dividends  Stock Splits
# count  3.856000e+03  3856.000000   3856.000000
# mean   4.537834e+09     0.379668      0.003112
# std    1.386343e+10    11.638912      0.164220
# min    1.486950e+05     0.000000      0.000000
# 25%    9.229050e+06     0.000000      0.000000
# 50%    3.304650e+07     0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Stock'],
#       dtype='object')

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                            Date        Open        High         Low  \
# 0     2024-02-15 00:00:00-05:00   19.642432   19.700574   19.564909
# 1     2024-02-16 00:00:00-05:00   19.719955   19.942834   19.632741
# 2     2024-02-20 00:00:00-05:00   19.652122   19.768405   19.371099
# 3     2024-02-21 00:00:00-05:00   19.177293   19.322649   19.070698
# 4     2024-02-22 00:00:00-05:00   19.574599   19.729645   19.516456
# ...                         ...         ...         ...         ...
# 3851  2025-02-11 00:00:00+00:00  200.358917  205.924194  195.321503
# 3852  2025-02-12 00:00:00+00:00  197.983856  198.449814  189.608429
# 3853  2025-02-13 00:00:00+00:00  196.773804  198.260757  189.427719
# 3854  2025-02-14 00:00:00+00:00  194.454559  205.125015  194.354050
# 3855  2025-02-16 00:00:00+00:00  194.474197  195.247986  193.230530
#
#            Close      Volume  Dividends  Stock Splits    Stock
# ...

# %%
import matplotlib.pyplot as plt
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Stock'],
#       dtype='object')

# %%
df.head()
from sklearn.preprocessing import  MinMaxScaler

# %%
print(df['High'].isnull().sum())
# Out:
# 0

# %%
df['High'].isna().sum()
# Out:
# np.int64(0)

# %%
df.hist(bins=15,figsize=(10,15))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Dividends'}>],
#        [<Axes: title={'center': 'Stock Splits'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns
g = sns.FacetGrid(df, col="Stock", col_wrap=4, height=3, aspect=1.2, sharey=False)
g.map(sns.lineplot, "Date", "Close", color="blue")
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Stock'],
#       dtype='object')

# %%
#df.drop(columns='Dividends',axis=0)
#df.drop(columns='Stock Splits',axis=0)

# %%
df.hist(bins=50,figsize=(15,20))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Dividends'}>],
#        [<Axes: title={'center': 'Stock Splits'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
dict
# Out:
# {'INFY':                          Date       Open       High        Low      Close  \
#  0   2024-02-15 00:00:00-05:00  19.642432  19.700574  19.564909  19.681192
#  1   2024-02-16 00:00:00-05:00  19.719955  19.942834  19.632741  19.836239
#  2   2024-02-20 00:00:00-05:00  19.652122  19.768405  19.371099  19.400171
#  3   2024-02-21 00:00:00-05:00  19.177293  19.322649  19.070698  19.167603
#  4   2024-02-22 00:00:00-05:00  19.574599  19.729645  19.516456  19.681192
#  ..                        ...        ...        ...        ...        ...
#  246 2025-02-10 00:00:00-05:00  21.799999  21.879999  21.709999  21.870001
#  247 2025-02-11 00:00:00-05:00  21.750000  21.990000  21.639999  21.969999
#  248 2025-02-12 00:00:00-05:00  21.590000  21.750000  21.510000  21.750000
#  249 2025-02-13 00:00:00-05:00  21.580000  21.760000  21.500000  21.740000
#  250 2025-02-14 00:00:00-05:00  21.730000  21.750000  21.540001  21.570000
#
#        Volume  Dividends  Stock Splits Stock
# ...

# %%
dict
# Out:
# {'INFY':                          Date       Open       High        Low      Close  \
#  0   2024-02-15 00:00:00-05:00  19.642432  19.700574  19.564909  19.681192
#  1   2024-02-16 00:00:00-05:00  19.719955  19.942834  19.632741  19.836239
#  2   2024-02-20 00:00:00-05:00  19.652122  19.768405  19.371099  19.400171
#  3   2024-02-21 00:00:00-05:00  19.177293  19.322649  19.070698  19.167603
#  4   2024-02-22 00:00:00-05:00  19.574599  19.729645  19.516456  19.681192
#  ..                        ...        ...        ...        ...        ...
#  246 2025-02-10 00:00:00-05:00  21.799999  21.879999  21.709999  21.870001
#  247 2025-02-11 00:00:00-05:00  21.750000  21.990000  21.639999  21.969999
#  248 2025-02-12 00:00:00-05:00  21.590000  21.750000  21.510000  21.750000
#  249 2025-02-13 00:00:00-05:00  21.580000  21.760000  21.500000  21.740000
#  250 2025-02-14 00:00:00-05:00  21.730000  21.750000  21.540001  21.570000
#
#        Volume  Dividends  Stock Splits Stock
# ...

# %%
dict.values()
# Out:
# dict_values([                         Date       Open       High        Low      Close  \
# 0   2024-02-15 00:00:00-05:00  19.642432  19.700574  19.564909  19.681192
# 1   2024-02-16 00:00:00-05:00  19.719955  19.942834  19.632741  19.836239
# 2   2024-02-20 00:00:00-05:00  19.652122  19.768405  19.371099  19.400171
# 3   2024-02-21 00:00:00-05:00  19.177293  19.322649  19.070698  19.167603
# 4   2024-02-22 00:00:00-05:00  19.574599  19.729645  19.516456  19.681192
# ..                        ...        ...        ...        ...        ...
# 246 2025-02-10 00:00:00-05:00  21.799999  21.879999  21.709999  21.870001
# 247 2025-02-11 00:00:00-05:00  21.750000  21.990000  21.639999  21.969999
# 248 2025-02-12 00:00:00-05:00  21.590000  21.750000  21.510000  21.750000
# 249 2025-02-13 00:00:00-05:00  21.580000  21.760000  21.500000  21.740000
# 250 2025-02-14 00:00:00-05:00  21.730000  21.750000  21.540001  21.570000
#
#       Volume  Dividends  Stock Splits Stock
# ...

# %%
d=df
d.hist(bins=10,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Dividends'}>],
#        [<Axes: title={'center': 'Stock Splits'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
#%pip install tensorflow

# %%
a=df['Stock']

# %%
# import tensorflow as tf
# print(tf.__version__)

# %%
df['High'].head()
# Out:
# 0    19.700574
# 1    19.942834
# 2    19.768405
# 3    19.322649
# 4    19.729645
# Name: High, dtype: float64

# %%
d=df
scaler=MinMaxScaler()
d['SHigh']=scaler.fit_transform(d[['High']])
d=d.drop(columns=['Dividends','Stock Splits'])
d.to_csv('data.csv')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3856 entries, 0 to 3855
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3856 non-null   object
#  1   Open    3856 non-null   float64
#  2   High    3856 non-null   float64
#  3   Low     3856 non-null   float64
#  4   Close   3856 non-null   float64
#  5   Volume  3856 non-null   int64
#  6   Stock   3856 non-null   object
#  7   SHigh   3856 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 241.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#d=d.drop(columns=['Date'],axis=0)

encode=LabelEncoder()
encoded_stock=encode.fit_transform(d[['Stock']])
print(encoded_stock)
# Out:
# [ 7  7  7 ... 12 12 12]
# d:\final_model\tf\final_project\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
enc_df=pd.DataFrame(encoded_stock)
enc_df
# Out:
#        0
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
# ...   ..
# 3851  12
# 3852  12
# 3853  12
# 3854  12
# 3855  12
#
# [3856 rows x 1 columns]

# %%
ed=pd.concat([d,enc_df],axis=1)
ed.rename(columns={0:'encoded_stock'},inplace=True)

# %%
ed.drop(columns=['Stock','Date'],inplace=True)
ed.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'SHigh', 'encoded_stock'], dtype='object')

# %%
len(ed['encoded_stock'].unique())
# Out:
# 14

# %%
ed['encoded_stock'].unique()
# Out:
# array([ 7,  1,  5, 13,  2,  0,  3, 11,  8,  6, 10,  4,  9, 12])

# %%
stocks #btc-usd,005930.ks,
# Out:
# ['INFY',
#  'AAPL',
#  'GOOGL',
#  'TSLA',
#  'BTC-USD',
#  '005930.KS',
#  'DOGE-USD',
#  'RELIANCE.NS',
#  'META',
#  'IBM',
#  'ORCL',
#  'ERF.PA',
#  'NVDA',
#  'SOL-USD']

# %%
import seaborn as sns
corr=ed.corr()
sns.heatmap(corr,cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
# c=ed.columns.tolist()
# for col in c:
#     sns.pairplot(ed, hue=col)

# %%
ed.to_csv("df.csv")
